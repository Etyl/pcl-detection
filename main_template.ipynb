# %% [markdown]
# # Main imports and code

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs, MultiLabelClassificationModel, MultiLabelClassificationArgs
from urllib import request
import pandas as pd
import logging
import torch
from collections import Counter
from ast import literal_eval
import random
import os
from sklearn.metrics import accuracy_score, f1_score


os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# prepare logger
logging.basicConfig(level=logging.INFO)

transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

# check gpu
cuda_available = torch.cuda.is_available()


print('Cuda available? ',cuda_available)
# Out:
# Cuda available?  True

# %%
torch.cuda.set_device(1)

# %% [markdown]
# # Fetch Don't Patronize Me! data manager module

# %%
module_url = f"https://raw.githubusercontent.com/Perez-AlmendrosC/dontpatronizeme/master/semeval-2022/dont_patronize_me.py"
module_name = module_url.split('/')[-1]
print(f'Fetching {module_url}')
#with open("file_1.txt") as f1, open("file_2.txt") as f2
with request.urlopen(module_url) as f, open(module_name,'w') as outf:
  a = f.read()
  outf.write(a.decode('utf-8'))
# Out:
# Fetching https://raw.githubusercontent.com/Perez-AlmendrosC/dontpatronizeme/master/semeval-2022/dont_patronize_me.py

# %%
# helper function to save predictions to an output file
def labels2file(p, outf_path):
	with open(outf_path,'w') as outf:
		for pi in p:
			outf.write(','.join([str(k) for k in pi])+'\n')

# %%
from dont_patronize_me import DontPatronizeMe

# %%
dpm = DontPatronizeMe('./data', './data')

# %%
dpm.load_task1()

# %% [markdown]
# # Load paragraph IDs

# %%
trids = pd.read_csv('./data/train_semeval_parids-labels.csv')
teids = pd.read_csv('./data/dev_semeval_parids-labels.csv')

# %%
trids.par_id = trids.par_id.astype(str)
teids.par_id = teids.par_id.astype(str)

# %%
data=dpm.train_task1_df

# %%
data
# Out:
#       par_id      art_id     keyword country  \
# 0          1  @@24942188    hopeless      ph
# 1          2  @@21968160     migrant      gh
# 2          3  @@16584954   immigrant      ie
# 3          4   @@7811231    disabled      nz
# 4          5   @@1494111     refugee      ca
# ...      ...         ...         ...     ...
# 10464  10465  @@14297363       women      lk
# 10465  10466  @@70091353  vulnerable      ph
# 10466  10467  @@20282330     in-need      ng
# 10467  10468  @@16753236    hopeless      in
# 10468  10469  @@16779383    homeless      ie
#
#                                                     text  label orig_label
# 0      We 're living in times of absolute insanity , ...      0          0
# 1      In Libya today , there are countless number of...      0          0
# 2      "White House press secretary Sean Spicer said ...      0          0
# 3      Council customers only signs would be displaye...      0          0
# 4      """ Just like we received migrants fleeing El ...      0          0
# ...                                                  ...    ...        ...
# 10464  "Sri Lankan norms and culture inhibit women fr...      0          1
# 10465  He added that the AFP will continue to bank on...      0          0
# 10466  """ She has one huge platform , and informatio...      1          3
# 10467  """ Anja Ringgren Loven I ca n't find a word t...      1          4
# 10468  """ Guinness World Record of 540lbs of 7-layer...      1          3
#
# [10469 rows x 7 columns]

# %% [markdown]
# # Rebuild training set (Task 1)

# %%
rows = [] # will contain par_id, label and text
for idx in range(len(trids)):
  parid = trids.par_id[idx]
  #print(parid)
  # select row from original dataset to retrieve `text` and binary label
  keyword = data.loc[data.par_id == parid].keyword.values[0]
  text = data.loc[data.par_id == parid].text.values[0]
  label = data.loc[data.par_id == parid].label.values[0]
  rows.append({
      'par_id':parid,
      'community':keyword,
      'text':text,
      'label':label
  })

# %%
trdf1 = pd.DataFrame(rows)

# %%
trdf1
# Out:
#      par_id      community                                               text  \
# 0      4341  poor-families  The scheme saw an estimated 150,000 children f...
# 1      4136       homeless  Durban 's homeless communities reconciliation ...
# 2     10352  poor-families  The next immediate problem that cropped up was...
# 3      8279     vulnerable  Far more important than the implications for t...
# 4      1164  poor-families  To strengthen child-sensitive social protectio...
# ...     ...            ...                                                ...
# 8370   8380        refugee  Rescue teams search for survivors on the rubbl...
# 8371   8381       hopeless  The launch of ' Happy Birthday ' took place la...
# 8372   8382       homeless  The unrest has left at least 20,000 people dea...
# 8373   8383       hopeless  You have to see it from my perspective . I may...
# 8374   8384       disabled  Yet there was one occasion when we went to the...
#
#       label
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 8370      0
# 8371      0
# 8372      0
# 8373      0
# 8374      0
#
# [8375 rows x 4 columns]

# %% [markdown]
# # Rebuild test set (Task 1)

# %%
rows = [] # will contain par_id, label and text
for idx in range(len(teids)):
  parid = teids.par_id[idx]
  #print(parid)
  # select row from original dataset
  keyword = data.loc[data.par_id == parid].keyword.values[0]
  text = data.loc[data.par_id == parid].text.values[0]
  label = data.loc[data.par_id == parid].label.values[0]
  rows.append({
      'par_id':parid,
      'community':keyword,
      'text':text,
      'label':label
  })

# %%
len(rows)
# Out:
# 2094

# %%
tedf1 = pd.DataFrame(rows)

# %%
tedf1.head()
# Out:
#   par_id community                                               text  label
# 0   4046  hopeless  We also know that they can benefit by receivin...      1
# 1   1279   refugee  Pope Francis washed and kissed the feet of Mus...      1
# 2   8330   refugee  Many refugees do n't want to be resettled anyw...      1
# 3   4063   in-need  "Budding chefs , like "" Fred "" , "" Winston ...      1
# 4   4089  homeless  "In a 90-degree view of his constituency , one...      1

# %% [markdown]
# # RoBERTa Baseline for Task 1

# %%
# downsample negative instances
pcldf = trdf1[trdf1.label==1]
npos = len(pcldf)

training_set1 = pd.concat([pcldf,trdf1[trdf1.label==0][:npos*2]])

# %%
training_set1
# Out:
#      par_id      community                                               text  \
# 0      4341  poor-families  The scheme saw an estimated 150,000 children f...
# 1      4136       homeless  Durban 's homeless communities reconciliation ...
# 2     10352  poor-families  The next immediate problem that cropped up was...
# 3      8279     vulnerable  Far more important than the implications for t...
# 4      1164  poor-families  To strengthen child-sensitive social protectio...
# ...     ...            ...                                                ...
# 2377   1775        refugee  Last but not the least element of culpability ...
# 2378   1776        refugee  Then , taking the art of counter-intuitive non...
# 2379   1777        refugee  Kagunga village was reported to lack necessary...
# 2380   1778     vulnerable  "After her parents high-profile divorce after ...
# 2381   1779        in-need  "Last night One News reported on leaked Minist...
#
#       label
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 2377      0
# 2378      0
# 2379      0
# 2380      0
# 2381      0
#
# [2382 rows x 4 columns]

# %%
task1_model_args = ClassificationArgs(num_train_epochs=1,
                                      no_save=True,
                                      no_cache=True,
                                      overwrite_output_dir=True,
                                      use_multiprocessing= False, 
                                      use_multiprocessing_for_evaluation=False,
                                      process_count= 1)

task1_model = ClassificationModel("roberta",
                                  'roberta-base',
                                  args = task1_model_args,
                                  num_labels=2,
                                  use_cuda=cuda_available,)
# train model
task1_model.train_model(training_set1[['text', 'label']])
# run predictions
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /home/infres/hverninas-22/miniconda3/lib/python3.12/site-packages/simpletransformers/classification/classification_model.py:610: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/infres/hverninas-22/miniconda3/lib/python3.12/site-packages/simpletransformers/classification/classification_model.py:882: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = amp.GradScaler()
# Running Epoch 1 of 1:   0%|          | 0/298 [00:00<?, ?it/s]
# /home/infres/hverninas-22/miniconda3/lib/python3.12/site-packages/simpletransformers/classification/classification_model.py:905: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# INFO:simpletransformers.classification.classification_model: Training of roberta model complete. Saved to outputs/.
# (298, 0.5328495251702382)

# %%
test_preds_task1, _ = task1_model.predict(tedf1.text.tolist())
# Out:
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/21 [00:00<?, ?it/s]
# /home/infres/hverninas-22/miniconda3/lib/python3.12/site-packages/simpletransformers/classification/classification_model.py:2188: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():

# %%
train_preds_task1, _ = task1_model.predict(trdf1.text.tolist())
# Out:
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/84 [00:00<?, ?it/s]

# %%
# Get true labels
test_true_labels = tedf1['label'].tolist()
train_true_labels = trdf1['label'].tolist()

print(f'Accuracy train: {accuracy_score(train_true_labels, train_preds_task1)}')
print(f'Accuracy test: {accuracy_score(test_true_labels, test_preds_task1)}')
print(f'F1 train: {f1_score(train_true_labels, train_preds_task1)}')
print(f'F1 test: {f1_score(test_true_labels, test_preds_task1)}')
# Out:
# Accuracy train: 0.8494328358208956
# Accuracy test: 0.8233046800382043
# F1 train: 0.5025641025641026
# F1 test: 0.4376899696048632

# %%
wrong_predictions_train = trdf1[train_preds_task1 != trdf1['label']][['par_id', 'text', 'label']]
# Add a column for text length and sort by it
wrong_predictions_train = wrong_predictions_train.assign(text_length=wrong_predictions_train.text.str.len())
wrong_predictions_train = wrong_predictions_train.sort_values(by="text_length", ascending=True).drop(columns=["text_length"])

# Print the first sentence along with its label
for row in wrong_predictions_train.iterrows():
    print(f"{row[1]["label"]}: {row[1]["text"]}")
# Out:
# par_id                    6021
# text      Pretty much hopeless
# label                        0
# Name: 6244, dtype: object: par_id                    6021
# text      Pretty much hopeless
# label                        0
# Name: 6244, dtype: object
# par_id                     5132
# text      Focus on the homeless
# label                         0
# Name: 5448, dtype: object: par_id                     5132
# text      Focus on the homeless
# label                         0
# Name: 5448, dtype: object
# par_id                        4003
# text      It just seems hopeless .
# label                            0
# Name: 4411, dtype: object: par_id                        4003
# text      It just seems hopeless .
# label                            0
# Name: 4411, dtype: object
# par_id                           6680
# text      Stephens in need of HK lift
# label                               0
# Name: 6831, dtype: object: par_id                           6680
# text      Stephens in need of HK lift
# label                               0
# Name: 6831, dtype: object
# par_id                            7322
# text      Luck that made them refugees
# label                                0
# Name: 7406, dtype: object: par_id                            7322
# text      Luck that made them refugees
# label                                0
# Name: 7406, dtype: object
# par_id                                 1434
# text      Volunteer helps earliest refugees
# label                                     0
# Name: 2067, dtype: object: par_id                                 1434
# text      Volunteer helps earliest refugees
# label                                     0
# Name: 2067, dtype: object
# par_id                                  2669
# text      Ebenezer - a home for the homeless
# label                                      0
# Name: 3197, dtype: object: par_id                                  2669
# text      Ebenezer - a home for the homeless
# label                                      0
# Name: 3197, dtype: object
# par_id                                   3879
# text      *Indicating that one feels hopeless
# label                                       0
# Name: 4297, dtype: object: par_id                                   3879
# text      *Indicating that one feels hopeless
# label                                       0
# Name: 4297, dtype: object
# par_id                                     6244
# text      @TheTruth -You are already hopeless .
# label                                         0
# Name: 6439, dtype: object: par_id                                     6244
# text      @TheTruth -You are already hopeless .
# label                                         0
# Name: 6439, dtype: object
# par_id                                     3350
# text      The disabled make strides in politics
# label                                         0
# Name: 3813, dtype: object: par_id                                     3350
# text      The disabled make strides in politics
# label                                         0
# Name: 3813, dtype: object
# par_id                                       4961
# text      ' Allocation to education is hopeless '
# label                                           0
# Name: 5294, dtype: object: par_id                                       4961
# text      ' Allocation to education is hopeless '
# label                                           0
# Name: 5294, dtype: object
# par_id                                        5769
# text      Where migrant women are the breadwinners
# label                                            0
# Name: 6023, dtype: object: par_id                                        5769
# text      Where migrant women are the breadwinners
# label                                            0
# Name: 6023, dtype: object
# par_id                                         6126
# text      Report paints picture of children in need
# label                                             0
# Name: 6334, dtype: object: par_id                                         6126
# text      Report paints picture of children in need
# label                                             0
# Name: 6334, dtype: object
# par_id                                            1966
# text      TASAF launches project to help poor families
# label                                                0
# Name: 2551, dtype: object: par_id                                            1966
# text      TASAF launches project to help poor families
# label                                                0
# Name: 2551, dtype: object
# par_id                                            3607
# text      News feed <h> Monash doc stands up for women
# label                                                1
# Name: 400, dtype: object: par_id                                            3607
# text      News feed <h> Monash doc stands up for women
# label                                                1
# Name: 400, dtype: object
# par_id                                            7156
# text      Feversham College students help the homeless
# label                                                0
# Name: 7258, dtype: object: par_id                                            7156
# text      Feversham College students help the homeless
# label                                                0
# Name: 7258, dtype: object
# par_id                                            4860
# text      1,188 homeless get jobs , return to families
# label                                                0
# Name: 5197, dtype: object: par_id                                            4860
# text      1,188 homeless get jobs , return to families
# label                                                0
# Name: 5197, dtype: object
# par_id                                             2389
# text      """ I was homeless and you gave me a home """
# label                                                 0
# Name: 2940, dtype: object: par_id                                             2389
# text      """ I was homeless and you gave me a home """
# label                                                 0
# Name: 2940, dtype: object
# par_id                                              2119
# text      Ed Mahama : Ghana drowning in ' hopelessness '
# label                                                  0
# Name: 2695, dtype: object: par_id                                              2119
# text      Ed Mahama : Ghana drowning in ' hopelessness '
# label                                                  0
# Name: 2695, dtype: object
# par_id                                                2281
# text      Mother awarded $207k for caring for disabled son
# label                                                    0
# Name: 2845, dtype: object: par_id                                                2281
# text      Mother awarded $207k for caring for disabled son
# label                                                    0
# Name: 2845, dtype: object
# par_id                                                  408
# text      VWO , Aware join hands to train needy in elder...
# label                                                     0
# Name: 1161, dtype: object: par_id                                                  408
# text      VWO , Aware join hands to train needy in elder...
# label                                                     0
# Name: 1161, dtype: object
# par_id                                                 7072
# text      Seeking aid abroad , Lebanon uproots Syrian re...
# label                                                     0
# Name: 7185, dtype: object: par_id                                                 7072
# text      Seeking aid abroad , Lebanon uproots Syrian re...
# label                                                     0
# Name: 7185, dtype: object
# par_id                                                 3581
# text      providing support to parents in need of assist...
# label                                                     0
# Name: 4025, dtype: object: par_id                                                 3581
# text      providing support to parents in need of assist...
# label                                                     0
# Name: 4025, dtype: object
# par_id                                                 6886
# text      The suspended miners say their situation is ho...
# label                                                     0
# Name: 7019, dtype: object: par_id                                                 6886
# text      The suspended miners say their situation is ho...
# label                                                     0
# Name: 7019, dtype: object
# par_id                                                 3328
# text      You are here <h> Brexit would hit poor familie...
# label                                                     0
# Name: 3792, dtype: object: par_id                                                 3328
# text      You are here <h> Brexit would hit poor familie...
# label                                                     0
# Name: 3792, dtype: object
# par_id                                                 5411
# text      Ghana athletics hopeless over gov't support - ...
# label                                                     0
# Name: 5702, dtype: object: par_id                                                 5411
# text      Ghana athletics hopeless over gov't support - ...
# label                                                     0
# Name: 5702, dtype: object
# par_id                                                 7089
# text      """ The situation is difficult but not hopeles...
# label                                                     0
# Name: 7202, dtype: object: par_id                                                 7089
# text      """ The situation is difficult but not hopeles...
# label                                                     0
# Name: 7202, dtype: object
# par_id                                                 2165
# text      GMA Kapuso Foundation reaches out to thousands...
# label                                                     0
# Name: 2738, dtype: object: par_id                                                 2165
# text      GMA Kapuso Foundation reaches out to thousands...
# label                                                     0
# Name: 2738, dtype: object
# par_id                                                   47
# text      More than 750 trolleys of food donated to thos...
# label                                                     0
# Name: 837, dtype: object: par_id                                                   47
# text      More than 750 trolleys of food donated to thos...
# label                                                     0
# Name: 837, dtype: object
# par_id                                                 2169
# text      Social venture gives sanitary supplies for wom...
# label                                                     0
# Name: 2741, dtype: object: par_id                                                 2169
# text      Social venture gives sanitary supplies for wom...
# label                                                     0
# Name: 2741, dtype: object
# par_id                                                 7941
# text      You are here <h> Still hopelessly devoted afte...
# label                                                     0
# Name: 7973, dtype: object: par_id                                                 7941
# text      You are here <h> Still hopelessly devoted afte...
# label                                                     0
# Name: 7973, dtype: object
# par_id                                                 3400
# text      Davao intensifies rescue of abandoned , homele...
# label                                                     0
# Name: 3855, dtype: object: par_id                                                 3400
# text      Davao intensifies rescue of abandoned , homele...
# label                                                     0
# Name: 3855, dtype: object
# par_id                                                 4335
# text      That 's what brings you to a real point of hop...
# label                                                     0
# Name: 4709, dtype: object: par_id                                                 4335
# text      That 's what brings you to a real point of hop...
# label                                                     0
# Name: 4709, dtype: object
# par_id                                                 3886
# text      Others took the post regarding homelessness in...
# label                                                     0
# Name: 4304, dtype: object: par_id                                                 3886
# text      Others took the post regarding homelessness in...
# label                                                     0
# Name: 4304, dtype: object
# par_id                                                 2045
# text      Volunteers repaint and tidy up homes of vulner...
# label                                                     0
# Name: 2624, dtype: object: par_id                                                 2045
# text      Volunteers repaint and tidy up homes of vulner...
# label                                                     0
# Name: 2624, dtype: object
# par_id                                                 4387
# text      Fake friends dem ... Only check you when dem i...
# label                                                     0
# Name: 4755, dtype: object: par_id                                                 4387
# text      Fake friends dem ... Only check you when dem i...
# label                                                     0
# Name: 4755, dtype: object
# par_id                                                 2489
# text      To the rescue : Nairobi sex workers who servic...
# label                                                     0
# Name: 3031, dtype: object: par_id                                                 2489
# text      To the rescue : Nairobi sex workers who servic...
# label                                                     0
# Name: 3031, dtype: object
# par_id                                                 4588
# text      Millions were left homeless and destitute afte...
# label                                                     0
# Name: 4942, dtype: object: par_id                                                 4588
# text      Millions were left homeless and destitute afte...
# label                                                     0
# Name: 4942, dtype: object
# par_id                                                 1954
# text      This must probably be the biggest hurdle for n...
# label                                                     1
# Name: 676, dtype: object: par_id                                                 1954
# text      This must probably be the biggest hurdle for n...
# label                                                     1
# Name: 676, dtype: object
# par_id                                                 5046
# text      In 2011 , Kunene found himself on the verge of...
# label                                                     0
# Name: 5371, dtype: object: par_id                                                 5046
# text      In 2011 , Kunene found himself on the verge of...
# label                                                     0
# Name: 5371, dtype: object
# par_id                                                 6052
# text      2017 Budget : More needs to be done for disabl...
# label                                                     1
# Name: 27, dtype: object: par_id                                                 6052
# text      2017 Budget : More needs to be done for disabl...
# label                                                     1
# Name: 27, dtype: object
# par_id                                                 6246
# text      Suhakam commends MBPJ for addressing the needs...
# label                                                     0
# Name: 6441, dtype: object: par_id                                                 6246
# text      Suhakam commends MBPJ for addressing the needs...
# label                                                     0
# Name: 6441, dtype: object
# par_id                                                  741
# text      Instal CEEs with the involvement of the vulner...
# label                                                     0
# Name: 1459, dtype: object: par_id                                                  741
# text      Instal CEEs with the involvement of the vulner...
# label                                                     0
# Name: 1459, dtype: object
# par_id                                                 2010
# text      Thousands of California college students homel...
# label                                                     0
# Name: 2590, dtype: object: par_id                                                 2010
# text      Thousands of California college students homel...
# label                                                     0
# Name: 2590, dtype: object
# par_id                                                 3981
# text      Fayval Williams hosts back to school treat for...
# label                                                     0
# Name: 4389, dtype: object: par_id                                                 3981
# text      Fayval Williams hosts back to school treat for...
# label                                                     0
# Name: 4389, dtype: object
# par_id                                                 4401
# text      He added that his wife is distraught at the ho...
# label                                                     0
# Name: 4768, dtype: object: par_id                                                 4401
# text      He added that his wife is distraught at the ho...
# label                                                     0
# Name: 4768, dtype: object
# par_id                                                 7341
# text      Egypt billionare offers to buy Mediterranean i...
# label                                                     1
# Name: 50, dtype: object: par_id                                                 7341
# text      Egypt billionare offers to buy Mediterranean i...
# label                                                     1
# Name: 50, dtype: object
# par_id                                                 6104
# text      Contractor ' takes off ' as Harambee Stars are...
# label                                                     0
# Name: 6314, dtype: object: par_id                                                 6104
# text      Contractor ' takes off ' as Harambee Stars are...
# label                                                     0
# Name: 6314, dtype: object
# par_id                                                 2776
# text      UN urges greater attention to plight of Haiti ...
# label                                                     0
# Name: 3295, dtype: object: par_id                                                 2776
# text      UN urges greater attention to plight of Haiti ...
# label                                                     0
# Name: 3295, dtype: object
# par_id                                                 3448
# text      News <h> Do n't have children you can not affo...
# label                                                     0
# Name: 3900, dtype: object: par_id                                                 3448
# text      News <h> Do n't have children you can not affo...
# label                                                     0
# Name: 3900, dtype: object
# par_id                                                 5045
# text      Tens of thousands are also in need in Burundi ...
# label                                                     0
# Name: 5370, dtype: object: par_id                                                 5045
# text      Tens of thousands are also in need in Burundi ...
# label                                                     0
# Name: 5370, dtype: object
# par_id                                                 7252
# text      Marawi in need of more food as end of Ramadan ...
# label                                                     0
# Name: 7345, dtype: object: par_id                                                 7252
# text      Marawi in need of more food as end of Ramadan ...
# label                                                     0
# Name: 7345, dtype: object
# par_id                                                 7748
# text      His death sparked a reaction to the refugee cr...
# label                                                     0
# Name: 7798, dtype: object: par_id                                                 7748
# text      His death sparked a reaction to the refugee cr...
# label                                                     0
# Name: 7798, dtype: object
# par_id                                                 4464
# text      Search smh : <h> Search in : <h> Church in nee...
# label                                                     0
# Name: 4829, dtype: object: par_id                                                 4464
# text      Search smh : <h> Search in : <h> Church in nee...
# label                                                     0
# Name: 4829, dtype: object
# par_id                                                 1627
# text      Woman raises over $150,000 for homeless man wh...
# label                                                     0
# Name: 2239, dtype: object: par_id                                                 1627
# text      Woman raises over $150,000 for homeless man wh...
# label                                                     0
# Name: 2239, dtype: object
# par_id                                                 1497
# text      """ I am anxious about homelessness and have s...
# label                                                     0
# Name: 2123, dtype: object: par_id                                                 1497
# text      """ I am anxious about homelessness and have s...
# label                                                     0
# Name: 2123, dtype: object
# par_id                                                 3996
# text      """ The women who are living it -- the inquiry...
# label                                                     0
# Name: 4404, dtype: object: par_id                                                 3996
# text      """ The women who are living it -- the inquiry...
# label                                                     0
# Name: 4404, dtype: object
# par_id                                                 4214
# text      TV Network uncovers abject poverty &amp; homel...
# label                                                     0
# Name: 4601, dtype: object: par_id                                                 4214
# text      TV Network uncovers abject poverty &amp; homel...
# label                                                     0
# Name: 4601, dtype: object
# par_id                                                 2703
# text      Selective kindness : In Europe , some refugees...
# label                                                     0
# Name: 3228, dtype: object: par_id                                                 2703
# text      Selective kindness : In Europe , some refugees...
# label                                                     0
# Name: 3228, dtype: object
# par_id                                                 6287
# text      When leadership is a problem , confusion reign...
# label                                                     0
# Name: 6476, dtype: object: par_id                                                 6287
# text      When leadership is a problem , confusion reign...
# label                                                     0
# Name: 6476, dtype: object
# par_id                                                 6638
# text      He said the items were meant to provide succou...
# label                                                     0
# Name: 6792, dtype: object: par_id                                                 6638
# text      He said the items were meant to provide succou...
# label                                                     0
# Name: 6792, dtype: object
# par_id                                                 1796
# text      The reasons why are the same reasons why anybo...
# label                                                     0
# Name: 2397, dtype: object: par_id                                                 1796
# text      The reasons why are the same reasons why anybo...
# label                                                     0
# Name: 2397, dtype: object
# par_id                                                 5571
# text      Slovenian artists donate works to Ljubljana ch...
# label                                                     0
# Name: 5840, dtype: object: par_id                                                 5571
# text      Slovenian artists donate works to Ljubljana ch...
# label                                                     0
# Name: 5840, dtype: object
# par_id                                                 4555
# text      To stand in the way of a homeless friendly pre...
# label                                                     0
# Name: 4911, dtype: object: par_id                                                 4555
# text      To stand in the way of a homeless friendly pre...
# label                                                     0
# Name: 4911, dtype: object
# par_id                                                 5856
# text      The UN food agency on Tuesday voiced concern f...
# label                                                     0
# Name: 6098, dtype: object: par_id                                                 5856
# text      The UN food agency on Tuesday voiced concern f...
# label                                                     0
# Name: 6098, dtype: object
# par_id                                                 4391
# text      He said the home for disabled children relied ...
# label                                                     0
# Name: 4759, dtype: object: par_id                                                 4391
# text      He said the home for disabled children relied ...
# label                                                     0
# Name: 4759, dtype: object
# par_id                                                10321
# text      Homeland star Mandy Patinkin : Fighting for re...
# label                                                     1
# Name: 644, dtype: object: par_id                                                10321
# text      Homeland star Mandy Patinkin : Fighting for re...
# label                                                     1
# Name: 644, dtype: object
# par_id                                                 5838
# text      The musical is anchored on Grace House , a wel...
# label                                                     0
# Name: 6083, dtype: object: par_id                                                 5838
# text      The musical is anchored on Grace House , a wel...
# label                                                     0
# Name: 6083, dtype: object
# par_id                                                 6850
# text      Few stories tug at the heartstrings as much as...
# label                                                     0
# Name: 6985, dtype: object: par_id                                                 6850
# text      Few stories tug at the heartstrings as much as...
# label                                                     0
# Name: 6985, dtype: object
# par_id                                                 2153
# text      """ The courts are not the place for a family ...
# label                                                     0
# Name: 2727, dtype: object: par_id                                                 2153
# text      """ The courts are not the place for a family ...
# label                                                     0
# Name: 2727, dtype: object
# par_id                                                 1917
# text      Anthony Torres was just trying to clean up aft...
# label                                                     0
# Name: 2508, dtype: object: par_id                                                 1917
# text      Anthony Torres was just trying to clean up aft...
# label                                                     0
# Name: 2508, dtype: object
# par_id                                                 5049
# text      Take us back to the moment just before the ide...
# label                                                     0
# Name: 5374, dtype: object: par_id                                                 5049
# text      Take us back to the moment just before the ide...
# label                                                     0
# Name: 5374, dtype: object
# par_id                                                 1655
# text      He added that he would be taking a break from ...
# label                                                     0
# Name: 2264, dtype: object: par_id                                                 1655
# text      He added that he would be taking a break from ...
# label                                                     0
# Name: 2264, dtype: object
# par_id                                                 7369
# text      """ I have sent working people into Focus Irel...
# label                                                     0
# Name: 7446, dtype: object: par_id                                                 7369
# text      """ I have sent working people into Focus Irel...
# label                                                     0
# Name: 7446, dtype: object
# par_id                                                 2711
# text      Financial , academic help opportunities availa...
# label                                                     0
# Name: 3235, dtype: object: par_id                                                 2711
# text      Financial , academic help opportunities availa...
# label                                                     0
# Name: 3235, dtype: object
# par_id                                                 2950
# text      Delores , St Andrew - physically challenged an...
# label                                                     0
# Name: 3446, dtype: object: par_id                                                 2950
# text      Delores , St Andrew - physically challenged an...
# label                                                     0
# Name: 3446, dtype: object
# par_id                                                 2018
# text      Soon it became a haven for destitute and despe...
# label                                                     0
# Name: 2598, dtype: object: par_id                                                 2018
# text      Soon it became a haven for destitute and despe...
# label                                                     0
# Name: 2598, dtype: object
# par_id                                                 6624
# text      I hope the poor families and people who now ha...
# label                                                     0
# Name: 6778, dtype: object: par_id                                                 6624
# text      I hope the poor families and people who now ha...
# label                                                     0
# Name: 6778, dtype: object
# par_id                                                 7695
# text      """ I felt hopeless because of my thinking and...
# label                                                     0
# Name: 7749, dtype: object: par_id                                                 7695
# text      """ I felt hopeless because of my thinking and...
# label                                                     0
# Name: 7749, dtype: object
# par_id                                                 2666
# text      Lilly-Hue : His ability to make sure our famil...
# label                                                     0
# Name: 3194, dtype: object: par_id                                                 2666
# text      Lilly-Hue : His ability to make sure our famil...
# label                                                     0
# Name: 3194, dtype: object
# par_id                                                  465
# text      Some of the report 's most disturbing facts we...
# label                                                     0
# Name: 1215, dtype: object: par_id                                                  465
# text      Some of the report 's most disturbing facts we...
# label                                                     0
# Name: 1215, dtype: object
# par_id                                                 6503
# text      """ We were literally a week away from being h...
# label                                                     0
# Name: 6666, dtype: object: par_id                                                 6503
# text      """ We were literally a week away from being h...
# label                                                     0
# Name: 6666, dtype: object
# par_id                                                 7007
# text      Many are poor families living in precarious ho...
# label                                                     0
# Name: 7124, dtype: object: par_id                                                 7007
# text      Many are poor families living in precarious ho...
# label                                                     0
# Name: 7124, dtype: object
# par_id                                                 4104
# text      Meet the disabled couple who create incredible...
# label                                                     0
# Name: 4502, dtype: object: par_id                                                 4104
# text      Meet the disabled couple who create incredible...
# label                                                     0
# Name: 4502, dtype: object
# par_id                                                 6890
# text      Alexis and her family decided to donate more t...
# label                                                     0
# Name: 7023, dtype: object: par_id                                                 6890
# text      Alexis and her family decided to donate more t...
# label                                                     0
# Name: 7023, dtype: object
# par_id                                                 6205
# text      "Sen ? Clochartaigh described them as "" the n...
# label                                                     0
# Name: 6403, dtype: object: par_id                                                 6205
# text      "Sen ? Clochartaigh described them as "" the n...
# label                                                     0
# Name: 6403, dtype: object
# par_id                                                 1116
# text      The increasing numbers of disabled in Pakistan...
# label                                                     0
# Name: 1790, dtype: object: par_id                                                 1116
# text      The increasing numbers of disabled in Pakistan...
# label                                                     0
# Name: 1790, dtype: object
# par_id                                                   38
# text      Rizvi : There will be no joy this Eid <h> ' Th...
# label                                                     0
# Name: 829, dtype: object: par_id                                                   38
# text      Rizvi : There will be no joy this Eid <h> ' Th...
# label                                                     0
# Name: 829, dtype: object
# par_id                                                 2960
# text      "He went on to urge women to learn from that a...
# label                                                     1
# Name: 524, dtype: object: par_id                                                 2960
# text      "He went on to urge women to learn from that a...
# label                                                     1
# Name: 524, dtype: object
# par_id                                                 4993
# text      90 percent of the youth are jobless , homeless...
# label                                                     0
# Name: 5322, dtype: object: par_id                                                 4993
# text      90 percent of the youth are jobless , homeless...
# label                                                     0
# Name: 5322, dtype: object
# par_id                                                 6692
# text      The food bank is a community-based organizatio...
# label                                                     0
# Name: 6839, dtype: object: par_id                                                 6692
# text      The food bank is a community-based organizatio...
# label                                                     0
# Name: 6839, dtype: object
# par_id                                                 3193
# text      There are numerous children in need of some ex...
# label                                                     0
# Name: 3668, dtype: object: par_id                                                 3193
# text      There are numerous children in need of some ex...
# label                                                     0
# Name: 3668, dtype: object
# par_id                                                 1449
# text      The event also raises money for charity Caudwe...
# label                                                     0
# Name: 2079, dtype: object: par_id                                                 1449
# text      The event also raises money for charity Caudwe...
# label                                                     0
# Name: 2079, dtype: object
# par_id                                                 7382
# text      Mark says he is considerate of that , but says...
# label                                                     0
# Name: 7457, dtype: object: par_id                                                 7382
# text      Mark says he is considerate of that , but says...
# label                                                     0
# Name: 7457, dtype: object
# par_id                                                 5462
# text      Detention should only be used as a last resort...
# label                                                     0
# Name: 5744, dtype: object: par_id                                                 5462
# text      Detention should only be used as a last resort...
# label                                                     0
# Name: 5744, dtype: object
# par_id                                                 1310
# text      MIKE SEXTON : David Holst 's hope is that the ...
# label                                                     0
# Name: 1962, dtype: object: par_id                                                 1310
# text      MIKE SEXTON : David Holst 's hope is that the ...
# label                                                     0
# Name: 1962, dtype: object
# par_id                                                 4379
# text      """ They do not know how many brothers , siste...
# label                                                     0
# Name: 4748, dtype: object: par_id                                                 4379
# text      """ They do not know how many brothers , siste...
# label                                                     0
# Name: 4748, dtype: object
# par_id                                                 7401
# text      """ I hope that they get justice for these poo...
# label                                                     0
# Name: 7473, dtype: object: par_id                                                 7401
# text      """ I hope that they get justice for these poo...
# label                                                     0
# Name: 7473, dtype: object
# par_id                                                  942
# text      """ No-one will ever understand how much it hu...
# label                                                     0
# Name: 1636, dtype: object: par_id                                                  942
# text      """ No-one will ever understand how much it hu...
# label                                                     0
# Name: 1636, dtype: object
# par_id                                                 5498
# text      They targeted the poor and students from Islam...
# label                                                     0
# Name: 5779, dtype: object: par_id                                                 5498
# text      They targeted the poor and students from Islam...
# label                                                     0
# Name: 5779, dtype: object
# par_id                                                  308
# text      But Coss was n't ready to see his son 's condi...
# label                                                     0
# Name: 1073, dtype: object: par_id                                                  308
# text      But Coss was n't ready to see his son 's condi...
# label                                                     0
# Name: 1073, dtype: object
# par_id                                                 5211
# text      Every alternate Saturday , the Doss family spe...
# label                                                     0
# Name: 5516, dtype: object: par_id                                                 5211
# text      Every alternate Saturday , the Doss family spe...
# label                                                     0
# Name: 5516, dtype: object
# par_id                                                 5062
# text      """ I did not have anywhere to sit . I had no ...
# label                                                     0
# Name: 5385, dtype: object: par_id                                                 5062
# text      """ I did not have anywhere to sit . I had no ...
# label                                                     0
# Name: 5385, dtype: object
# par_id                                                 4954
# text      """ However , at the same time , three familie...
# label                                                     0
# Name: 5288, dtype: object: par_id                                                 4954
# text      """ However , at the same time , three familie...
# label                                                     0
# Name: 5288, dtype: object
# par_id                                                 5802
# text      Raising the nutrition level of children aged f...
# label                                                     0
# Name: 6052, dtype: object: par_id                                                 5802
# text      Raising the nutrition level of children aged f...
# label                                                     0
# Name: 6052, dtype: object
# par_id                                                 3884
# text      play onlookers had to comfort the young homele...
# label                                                     0
# Name: 4302, dtype: object: par_id                                                 3884
# text      play onlookers had to comfort the young homele...
# label                                                     0
# Name: 4302, dtype: object
# par_id                                                 2340
# text      The evicted people were homeless and deprived ...
# label                                                     0
# Name: 2898, dtype: object: par_id                                                 2340
# text      The evicted people were homeless and deprived ...
# label                                                     0
# Name: 2898, dtype: object
# par_id                                                 5874
# text      The man by the name Simon Kimely had given up ...
# label                                                     0
# Name: 6114, dtype: object: par_id                                                 5874
# text      The man by the name Simon Kimely had given up ...
# label                                                     0
# Name: 6114, dtype: object
# par_id                                                   17
# text      For those few seconds , humanity is free of it...
# label                                                     0
# Name: 810, dtype: object: par_id                                                   17
# text      For those few seconds , humanity is free of it...
# label                                                     0
# Name: 810, dtype: object
# par_id                                                 5835
# text      At least 400,000 hungry and traumatised refuge...
# label                                                     1
# Name: 641, dtype: object: par_id                                                 5835
# text      At least 400,000 hungry and traumatised refuge...
# label                                                     1
# Name: 641, dtype: object
# par_id                                                 7458
# text      The 21-year old was kept on life support until...
# label                                                     0
# Name: 7526, dtype: object: par_id                                                 7458
# text      The 21-year old was kept on life support until...
# label                                                     0
# Name: 7526, dtype: object
# par_id                                                 2640
# text      This was a typical response to victims from po...
# label                                                     1
# Name: 788, dtype: object: par_id                                                 2640
# text      This was a typical response to victims from po...
# label                                                     1
# Name: 788, dtype: object
# par_id                                                 5010
# text      """ The money earned by child family members h...
# label                                                     0
# Name: 5338, dtype: object: par_id                                                 5010
# text      """ The money earned by child family members h...
# label                                                     0
# Name: 5338, dtype: object
# par_id                                                  712
# text      The fate of nearly 790,000 young undocumented ...
# label                                                     1
# Name: 247, dtype: object: par_id                                                  712
# text      The fate of nearly 790,000 young undocumented ...
# label                                                     1
# Name: 247, dtype: object
# par_id                                                 2493
# text      JOBURG -- The Salvation Army requests donation...
# label                                                     0
# Name: 3035, dtype: object: par_id                                                 2493
# text      JOBURG -- The Salvation Army requests donation...
# label                                                     0
# Name: 3035, dtype: object
# par_id                                                 6648
# text      On Monday night , Lau joined seven other lawma...
# label                                                     0
# Name: 6800, dtype: object: par_id                                                 6648
# text      On Monday night , Lau joined seven other lawma...
# label                                                     0
# Name: 6800, dtype: object
# par_id                                                  784
# text      Phamotse is now on a mission to educate young ...
# label                                                     0
# Name: 1499, dtype: object: par_id                                                  784
# text      Phamotse is now on a mission to educate young ...
# label                                                     0
# Name: 1499, dtype: object
# par_id                                                 6140
# text      We now have free text books and subsidized bus...
# label                                                     0
# Name: 6343, dtype: object: par_id                                                 6140
# text      We now have free text books and subsidized bus...
# label                                                     0
# Name: 6343, dtype: object
# par_id                                                 2807
# text      All the youths are from poor families , workin...
# label                                                     0
# Name: 3320, dtype: object: par_id                                                 2807
# text      All the youths are from poor families , workin...
# label                                                     0
# Name: 3320, dtype: object
# par_id                                                 6481
# text      For a country sorely in need of a uniting forc...
# label                                                     0
# Name: 6646, dtype: object: par_id                                                 6481
# text      For a country sorely in need of a uniting forc...
# ...
# label                                                     1
# Name: 76, dtype: object: par_id                                                 3580
# text      "The 19th century figure of misfortune is conj...
# label                                                     1
# Name: 76, dtype: object
# par_id                                                 5577
# text      """ Welfare of the masses and improving their ...
# label                                                     0
# Name: 5846, dtype: object: par_id                                                 5577
# text      """ Welfare of the masses and improving their ...
# label                                                     0
# Name: 5846, dtype: object
# par_id                                                 7213
# text      According to the data of the National Disaster...
# label                                                     1
# Name: 537, dtype: object: par_id                                                 7213
# text      According to the data of the National Disaster...
# label                                                     1
# Name: 537, dtype: object
# par_id                                                 6517
# text      """ Kaput , kaput , alles kaput "" may sound r...
# label                                                     0
# Name: 6678, dtype: object: par_id                                                 6517
# text      """ Kaput , kaput , alles kaput "" may sound r...
# label                                                     0
# Name: 6678, dtype: object
# par_id                                                 8292
# text      This entire year , instead of being inspired a...
# label                                                     0
# Name: 8287, dtype: object: par_id                                                 8292
# text      This entire year , instead of being inspired a...
# label                                                     0
# Name: 8287, dtype: object
# par_id                                                  777
# text      How these debates play out will have an import...
# label                                                     0
# Name: 1492, dtype: object: par_id                                                  777
# text      How these debates play out will have an import...
# label                                                     0
# Name: 1492, dtype: object
# par_id                                                 1072
# text      "It is just a difference in need . Equality is...
# label                                                     0
# Name: 1750, dtype: object: par_id                                                 1072
# text      "It is just a difference in need . Equality is...
# label                                                     0
# Name: 1750, dtype: object
# par_id                                                 1924
# text      The most vulnerable in our society are barely ...
# label                                                     0
# Name: 2514, dtype: object: par_id                                                 1924
# text      The most vulnerable in our society are barely ...
# label                                                     0
# Name: 2514, dtype: object
# par_id                                                 7407
# text      No right-thinking person could seriously consi...
# label                                                     1
# Name: 197, dtype: object: par_id                                                 7407
# text      No right-thinking person could seriously consi...
# label                                                     1
# Name: 197, dtype: object
# par_id                                                 7463
# text      But do n't forget as the title subtly but unmi...
# label                                                     1
# Name: 751, dtype: object: par_id                                                 7463
# text      But do n't forget as the title subtly but unmi...
# label                                                     1
# Name: 751, dtype: object
# par_id                                                 3544
# text      "BARA : The Pakistan Red Crescent Society ( PR...
# label                                                     0
# Name: 3990, dtype: object: par_id                                                 3544
# text      "BARA : The Pakistan Red Crescent Society ( PR...
# label                                                     0
# Name: 3990, dtype: object
# par_id                                                 6552
# text      "-- In 2014 Make the Future showcased Pavegen ...
# label                                                     1
# Name: 786, dtype: object: par_id                                                 6552
# text      "-- In 2014 Make the Future showcased Pavegen ...
# label                                                     1
# Name: 786, dtype: object
# par_id                                                 7797
# text      I 'm sorry to say that the average Nigerian wo...
# label                                                     1
# Name: 239, dtype: object: par_id                                                 7797
# text      I 'm sorry to say that the average Nigerian wo...
# label                                                     1
# Name: 239, dtype: object
# par_id                                                 4502
# text      "Ryan says he plans to serve out the remainder...
# label                                                     1
# Name: 222, dtype: object: par_id                                                 4502
# text      "Ryan says he plans to serve out the remainder...
# label                                                     1
# Name: 222, dtype: object
# par_id                                                  165
# text      Though many tribes now feel a need to educate ...
# label                                                     0
# Name: 945, dtype: object: par_id                                                  165
# text      Though many tribes now feel a need to educate ...
# label                                                     0
# Name: 945, dtype: object
# par_id                                                 7051
# text      Students from the rural poor communities of Gh...
# label                                                     0
# Name: 7165, dtype: object: par_id                                                 7051
# text      Students from the rural poor communities of Gh...
# label                                                     0
# Name: 7165, dtype: object
# par_id                                                 5676
# text      "Healthcare should not be political . Every mo...
# label                                                     0
# Name: 5939, dtype: object: par_id                                                 5676
# text      "Healthcare should not be political . Every mo...
# label                                                     0
# Name: 5939, dtype: object
# par_id                                                 5797
# text      China and Sri Lanka are friends in need . The ...
# label                                                     0
# Name: 6048, dtype: object: par_id                                                 5797
# text      China and Sri Lanka are friends in need . The ...
# label                                                     0
# Name: 6048, dtype: object
# par_id                                                 5971
# text      Many have placed their faith in the belief tha...
# label                                                     0
# Name: 6203, dtype: object: par_id                                                 5971
# text      Many have placed their faith in the belief tha...
# label                                                     0
# Name: 6203, dtype: object
# par_id                                                 4777
# text      Still , all 's well that ends well , at least ...
# label                                                     0
# Name: 5117, dtype: object: par_id                                                 4777
# text      Still , all 's well that ends well , at least ...
# label                                                     0
# Name: 5117, dtype: object
# par_id                                                 5800
# text      """ We are sad . We are angry . We feel totall...
# label                                                     0
# Name: 6050, dtype: object: par_id                                                 5800
# text      """ We are sad . We are angry . We feel totall...
# label                                                     0
# Name: 6050, dtype: object
# par_id                                                 5980
# text      Kennedy House Youth Services Inc. is excited t...
# label                                                     0
# Name: 6209, dtype: object: par_id                                                 5980
# text      Kennedy House Youth Services Inc. is excited t...
# label                                                     0
# Name: 6209, dtype: object
# par_id                                                  470
# text      "I 've been in the business world for 30 years...
# label                                                     0
# Name: 1220, dtype: object: par_id                                                  470
# text      "I 've been in the business world for 30 years...
# label                                                     0
# Name: 1220, dtype: object
# par_id                                                 3474
# text      They have raised a series A round of funding a...
# label                                                     0
# Name: 3923, dtype: object: par_id                                                 3474
# text      They have raised a series A round of funding a...
# label                                                     0
# Name: 3923, dtype: object
# par_id                                                 5068
# text      One wonders why our politicians , especially t...
# label                                                     0
# Name: 5391, dtype: object: par_id                                                 5068
# text      One wonders why our politicians , especially t...
# label                                                     0
# Name: 5391, dtype: object
# par_id                                                 1800
# text      "At Davos , the World Economic Forum dedicated...
# label                                                     1
# Name: 368, dtype: object: par_id                                                 1800
# text      "At Davos , the World Economic Forum dedicated...
# label                                                     1
# Name: 368, dtype: object
# par_id                                                 1037
# text      He called on all alumni to realise that people...
# label                                                     0
# Name: 1719, dtype: object: par_id                                                 1037
# text      He called on all alumni to realise that people...
# label                                                     0
# Name: 1719, dtype: object
# par_id                                                 5236
# text      "She is saddened by the futility of war and at...
# label                                                     0
# Name: 5539, dtype: object: par_id                                                 5236
# text      "She is saddened by the futility of war and at...
# label                                                     0
# Name: 5539, dtype: object
# par_id                                                   78
# text      "But Prabha was one of the few fortunate women...
# label                                                     0
# Name: 867, dtype: object: par_id                                                   78
# text      "But Prabha was one of the few fortunate women...
# label                                                     0
# Name: 867, dtype: object
# par_id                                                 5324
# text      "There are people in our society who have trou...
# label                                                     0
# Name: 5619, dtype: object: par_id                                                 5324
# text      "There are people in our society who have trou...
# label                                                     0
# Name: 5619, dtype: object
# par_id                                                 6057
# text      The core beliefs that form the CHOGM 's charte...
# label                                                     0
# Name: 6272, dtype: object: par_id                                                 6057
# text      The core beliefs that form the CHOGM 's charte...
# label                                                     0
# Name: 6272, dtype: object
# par_id                                                 2753
# text      "Natasha Carswell , NCC 's Manager Community S...
# label                                                     0
# Name: 3273, dtype: object: par_id                                                 2753
# text      "Natasha Carswell , NCC 's Manager Community S...
# label                                                     0
# Name: 3273, dtype: object
# par_id                                                 3287
# text      It was past noon when we came to her home amid...
# label                                                     0
# Name: 3754, dtype: object: par_id                                                 3287
# text      It was past noon when we came to her home amid...
# label                                                     0
# Name: 3754, dtype: object
# par_id                                                 4628
# text      I express solidarity with this time-appropriat...
# label                                                     0
# Name: 4979, dtype: object: par_id                                                 4628
# text      I express solidarity with this time-appropriat...
# label                                                     0
# Name: 4979, dtype: object
# par_id                                                 7742
# text      I help run a nonprofit called Boulder Food Res...
# label                                                     0
# Name: 7792, dtype: object: par_id                                                 7742
# text      I help run a nonprofit called Boulder Food Res...
# label                                                     0
# Name: 7792, dtype: object
# par_id                                                 7412
# text      The LGBT movement has created vast opportuniti...
# label                                                     0
# Name: 7483, dtype: object: par_id                                                 7412
# text      The LGBT movement has created vast opportuniti...
# label                                                     0
# Name: 7483, dtype: object
# par_id                                                 5188
# text      Hyderabad -- The Sindh minister for social wel...
# label                                                     0
# Name: 5496, dtype: object: par_id                                                 5188
# text      Hyderabad -- The Sindh minister for social wel...
# label                                                     0
# Name: 5496, dtype: object
# par_id                                                 6315
# text      "I ran into one of my high school teachers rec...
# label                                                     0
# Name: 6500, dtype: object: par_id                                                 6315
# text      "I ran into one of my high school teachers rec...
# label                                                     0
# Name: 6500, dtype: object
# par_id                                                 7853
# text      "Islamic philosophy has dealt at length with t...
# label                                                     1
# Name: 25, dtype: object: par_id                                                 7853
# text      "Islamic philosophy has dealt at length with t...
# label                                                     1
# Name: 25, dtype: object

# %%
Counter(test_preds_task1)
# Out:
# Counter({np.int64(0): 1718, np.int64(1): 376})

# %%
labels2file([[k] for k in test_preds_task1], 'task1.txt')

# %% [markdown]
# ## Prepare submission

# %%
# !cat task1.txt | head -n 10
# Out:
# 0
# 1
# 0
# 1
# 0
# 0
# 1
# 1
# 0
# 1

# %%
# !zip submission.zip task1.txt
# Out:
#   adding: task1.txt (deflated 92%)
